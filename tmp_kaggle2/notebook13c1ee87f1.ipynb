# %%
# %%bash
# cd /kaggle/working
# git clone https://github.com/bayntun/Nemotron-training.git
# Out:
# Cloning into 'Nemotron-training'...

# %%
# %%bash
# set -eux
# cd /kaggle/working/Nemotron-training
# pip install -q -r requirements.txt
# python scripts/benchmark_gpu.py \
#   --batch 4 --seq 256 --hidden 3072 --layers 10 \
#   --warmup 5 --steps 25 --dtype fp16
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.4/46.4 kB 2.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.7/40.7 kB 1.5 MB/s eta 0:00:00
# + cd /kaggle/working/Nemotron-training
# + pip install -q -r requirements.txt
# + python scripts/benchmark_gpu.py --batch 4 --seq 256 --hidden 3072 --layers 10 --warmup 5 --steps 25 --dtype fp16
# Traceback (most recent call last):
#   File "/kaggle/working/Nemotron-training/scripts/benchmark_gpu.py", line 129, in <module>
#     main()
#   File "/kaggle/working/Nemotron-training/scripts/benchmark_gpu.py", line 66, in main
#     raise RuntimeError("CUDA is required for this benchmark")
# RuntimeError: CUDA is required for this benchmark
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /tmp/ipykernel_57/3101881897.py in <cell line: 0>()
# ...
